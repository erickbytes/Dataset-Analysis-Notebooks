# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.dates as mdates

# https://data.world/sports/ncaa-mens-march-madness
file_path = 'sports-ncaa-mens-march-madness/data/ncaa_mens_march_madness_historical_results.csv'
df = pd.read_csv(file_path, delimiter=",", index_col=None, encoding = "ISO-8859-1") # engine='python', encoding='utf-8'
wins_df = df[df['winner']=='Illinois']
losses_df = df[df['loser']=='Illinois']
print(wins_df.index.size)
print(losses_df.index.size)
print(wins_df.head())
list_of_datetimes = pd.to_datetime(wins_df['date'])
dates = mdates.date2num(list_of_datetimes)
values = wins_df['round']
years = mdates.YearLocator()
fig, ax = plt.subplots(1,1)
fig.set_figheight(10)
fig.set_figwidth(10)
ax.xaxis.set_major_locator(years)
plt.rcParams.update({'font.size': 12})
plt.plot_date(dates, values, color='orange', markersize=12) #linestyle='solid'
plt.xticks(rotation=50)
plt.title('University of Illinois NCAA Tourney Wins Since 1985', fontsize=14)

#plt.bar(dates, values)
# Out:
# 28
# 22
#            date        round     region  winning_seed    winner  \
# 17   1985-03-15  Round of 64       East             3  Illinois
# 41   1985-03-17  Round of 32       East             3  Illinois
# 88   1986-03-14  Round of 64  Southeast             4  Illinois
# 214  1988-03-18  Round of 64  Southeast             3  Illinois
# 256  1989-03-16  Round of 64    Midwest             1  Illinois
#
#      winning_score  losing_seed              loser  losing_score overtime
# 17              76           14       Northeastern            57      NaN
# 41              74            6            Georgia            58      NaN
# 88              75           13          Fairfield            51      NaN
# 214             81           14  Texas-San Antonio            72      NaN
# 256             77           16      McNeese State            71      NaN
# Text(0.5, 1.0, 'University of Illinois NCAA Tourney Wins Since 1985')
