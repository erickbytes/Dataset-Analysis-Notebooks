# %%
# https://data.world/awram/food-nutritional-values
import pandas as pd
df = pd.read_excel('ABBREV.xlsx')
df = df.sort_values(by=['Sugar_Tot_(g)'], ascending=False)
df = df[df.Shrt_Desc.str.contains('COFFEE,')]
df = df.nlargest(10, 'Sugar_Tot_(g)')
df.plot(x='Shrt_Desc', y='Sugar_Tot_(g)', kind="bar", color='DarkBlue', legend=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel('ABBREV.xlsx')
df = df.sort_values(by=['Sugar_Tot_(g)'], ascending=False)
df = df[df.Shrt_Desc.str.contains('CEREALS,')] #& (~df.Shrt_Desc.str.contains('OATMEAL,'))
df = df.nlargest(15, 'Sugar_Tot_(g)')
df.plot.barh(x='Shrt_Desc', y='Sugar_Tot_(g)',color='DarkBlue', legend=False)
plt.xlabel(xlabel='Grams of Sugar')
plt.title('Most Sugar, Cereals - USDA', fontsize=14)
plt.gca().invert_yaxis()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel('ABBREV.xlsx')
df = df.sort_values(by=['Sugar_Tot_(g)'], ascending=True)
df = df[(df.Shrt_Desc.str.contains('WINE') | df.Shrt_Desc.str.contains('BEER')) & (df.Shrt_Desc.str.contains('BEV')) & (~df.Shrt_Desc.str.contains('NON-ALCOHOLIC'))] #
df = df.nlargest(12, 'Sugar_Tot_(g)')
print(df['Shrt_Desc'])
df.plot.barh(x='Shrt_Desc', y='Sugar_Tot_(g)',color='DarkBlue', legend=False)
plt.gca().invert_yaxis()
plt.title('Most Sugar, Beer or Wine Beverages - USDA', fontsize=14)
plt.savefig('Most Sugar, Beer or Wine Beverages - USDA.png', bbox_inches='tight')
# Out:
# 4236                     BEVERAGES,CARB,ROOT BEER
# 4299        ALCOHOLIC BEV,MALT BEER,HARD LEMONADE
# 4162                 ALCOHOLIC BEV,WINE,DSSRT,SWT
# 4311                ALCOHOLIC BEVERAGES,WINE,ROSE
# 8674                   ALCOHOLIC BEV,WINE,COOKING
# 8675                        ALCOHOLIC BEV,WINE,LT
# 4418                 ALCOHOLIC BEV,WINE,DSSRT,DRY
# 4239    ALCOHOLIC BEV,WINE,TABLE,WHITE,CHARDONNAY
# 4200               ALCOHOLIC BEV,WINE,TABLE,WHITE
# 4182                 ALCOHOLIC BEV,WINE,TABLE,ALL
# 4437          ALCOHOLIC BEV,WINE,TABLE,RED,MERLOT
# 4191                 ALCOHOLIC BEV,WINE,TABLE,RED
# Name: Shrt_Desc, dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel('ABBREV.xlsx')
df = df.sort_values(by=['Sugar_Tot_(g)'], ascending=True)
df = df[(df.Shrt_Desc.str.contains('CARB') & (df.Shrt_Desc.str.contains('BEV')))] #
df = df.nlargest(12, 'Sugar_Tot_(g)')
print(df['Shrt_Desc'])
df.plot.barh(x='Shrt_Desc', y='Sugar_Tot_(g)',color='DarkBlue', legend=False)
plt.gca().invert_yaxis()
plt.title('Most Sugar, Beverages - USDA', fontsize=14)
plt.savefig('Most Sugar, Beverages - USD.png', bbox_inches='tight')
# Out:
# 4165    BEVERAGES,ENERGY DRK W/ CARB H2O & HI FRUCTOSE...
# 4213                              CARBONATED BEV,CRM SODA
# 4429               CARBONATED BEV,CHOCOLATE-FLAVORED SODA
# 4236                             BEVERAGES,CARB,ROOT BEER
# 4226                     BEVERAGES,CARB,COLA,WO/ CAFFEINE
# 4223           BEVERAGES,CARB,LEMON-LIME SODA,NO CAFFEINE
# 4227                              BEVERAGES,CARB,COLA,REG
# 4224        BEVERAGES,CARB,SPRITE,LEMON-LIME,WO/ CAFFEINE
# 4377                   BEVERAGES,CARB,COLA,FAST-FOOD COLA
# 4217                            BEVERAGES,CARB,GINGER ALE
# 4234                             BEVERAGES,CARB,TONIC H2O
# 4228    BEVERAGES,CARB,RED SUGAR,COLA,CONTAINS CAFFEIN...
# Name: Shrt_Desc, dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel('ABBREV.xlsx')
df = df.sort_values(by=['Sugar_Tot_(g)'], ascending=True)
df = df[(df.Shrt_Desc.str.contains('BREAD,')) & (df.Shrt_Desc.str.contains('WHEAT') | df.Shrt_Desc.str.contains('WHITE'))] #
df = df.nlargest(12, 'Sugar_Tot_(g)')
print(df['Shrt_Desc'])
df.plot.barh(x='Shrt_Desc', y='Sugar_Tot_(g)',color='DarkBlue', legend=False)
plt.gca().invert_yaxis()
plt.title('Most Sugar, Wheat Vs. White Bread - USDA', fontsize=14)
plt.savefig('Most Sugar, Wheat Vs. White Bread - USDA.png', bbox_inches='tight')
# Out:
# 5612                                    BREAD,WHEAT BRAN
# 5611                                  BREAD, WHEAT, TSTD
# 5614                        BREAD,WHITE,COMMLY PREP,TSTD
# 5618            BREAD, WHOLE-WHEAT, COMMER PREP, TOASTED
# 5610                                         BREAD,WHEAT
# 5613    BREAD,WHITE,COMMLY PREP (INCL SOFT BREAD CRUMBS)
# 6015                                   BREAD,WHITE WHEAT
# 5606                                 BREAD,RED-CAL,WHITE
# 5617                    BREAD,WHOLE-WHEAT,COMM. PREPARED
# 5882               BREAD,WHITE,COMMLY PREP,LO NA,NO SALT
# 5620             BREAD,WHOLE-WHEAT,PREP FROM RECIPE,TSTD
# 8088             BREAD,PARATHA,WHL WHEAT,COMMLY PREP,FRZ
# Name: Shrt_Desc, dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel('ABBREV.xlsx')
df = df.sort_values(by=['Carbohydrt_(g)'], ascending=True)
df = df[(df.Shrt_Desc.str.contains('BREAD,')) & (df.Shrt_Desc.str.contains('WHEAT') | df.Shrt_Desc.str.contains('WHITE'))] #
df = df.nlargest(12, 'Carbohydrt_(g)')
print(df['Shrt_Desc'])
df.plot.barh(x='Shrt_Desc', y='Carbohydrt_(g)',color='DarkBlue', legend=False)
plt.style.use('seaborn-pastel')
plt.gca().invert_yaxis()
plt.title('Most Sugar, Wheat Vs. White Bread - USDA', fontsize=14)
plt.savefig('Most Sugar, Wheat Vs. White Bread - USDA.png', bbox_inches='tight')
# Out:
# 6578                             WHEAT FLOURS,BREAD,UNENR
# 6545                            WHEAT FLR,WHITE,BREAD,ENR
# 5620              BREAD,WHOLE-WHEAT,PREP FROM RECIPE,TSTD
# 5595                               BREAD,PITA,WHOLE-WHEAT
# 5611                                   BREAD, WHEAT, TSTD
# 5594                            BREAD,PITA,WHITE,ENRICHED
# 5880                               BREAD,PITA,WHITE,UNENR
# 5614                         BREAD,WHITE,COMMLY PREP,TSTD
# 5898           BREAD,WHITE,COMMLY PREP,TSTD,LO NA NO SALT
# 5866                             BREAD,WHEAT GERM,TOASTED
# 5615    BREAD,WHITE,PREP FROM RECIPE,MADE W/NONFAT DRY...
# 5619                   BREAD,WHOLE-WHEAT,PREP FROM RECIPE
# Name: Shrt_Desc, dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel('ABBREV.xlsx')
df = df.sort_values(by=['Carbohydrt_(g)'], ascending=True)
white_df = df[(df.Shrt_Desc.str.contains('BREAD,')) & (df.Shrt_Desc.str.contains('WHEAT'))] #
wheat_df = df[(df.Shrt_Desc.str.contains('BREAD,')) & (df.Shrt_Desc.str.contains('WHITE'))] 
white_mean = white_df['Carbohydrt_(g)'].mean()
wheat_mean = wheat_df['Carbohydrt_(g)'].mean()
                                                       
print(white_df.index.size)
print(wheat_df.index.size)
print(white_mean)
print(wheat_mean)
                                                       
                                                       
# df = df.nlargest(12, 'Carbohydrt_(g)')
# print(df['Shrt_Desc'])
# df.plot.barh(x='Shrt_Desc', y='Carbohydrt_(g)',color='DarkBlue', legend=False)
# plt.gca().invert_yaxis()
# plt.title('Most Sugar, Wheat Vs. White Bread - USDA', fontsize=14)
# plt.savefig('Most Sugar, Wheat Vs. White Bread - USDA.png', bbox_inches='tight')
# Out:
# 20
# 11
# 50.07
# 53.02363636363636

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel('ABBREV.xlsx')
df = df.sort_values(by=['Iron_(mg)'], ascending=True)
df = df[(~df.Shrt_Desc.str.contains('BABYFOOD'))] #
df = df.nlargest(50, 'Iron_(mg)')
df.plot.barh(x='Shrt_Desc', y='Iron_(mg)',color='DarkBlue', legend=False, figsize=(15,10))
plt.gca().invert_yaxis()
plt.style.use('seaborn-pastel')
plt.xlabel(xlabel='Milligrams of Iron')
ax1 = plt.axes()
ax1.yaxis.label.set_visible(False)
plt.title('Foods With The Most Iron - USDA (2015)', fontsize=14)
plt.savefig('Foods with The Most Iron - USDA 2015.png', bbox_inches='tight')
# Out:
# /home/erick/Desktop/Projects/Sandbox/lib/python3.5/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %%
print(plt.style.available)
# Out:
# ['seaborn-dark', '_classic_test', 'bmh', 'Solarize_Light2', 'seaborn-poster', 'seaborn-pastel', 'ggplot', 'dark_background', 'fivethirtyeight', 'seaborn-darkgrid', 'seaborn-whitegrid', 'seaborn-ticks', 'seaborn-deep', 'seaborn-dark-palette', 'seaborn-talk', 'seaborn', 'seaborn-notebook', 'seaborn-colorblind', 'seaborn-muted', 'fast', 'seaborn-bright', 'grayscale', 'tableau-colorblind10', 'classic', 'seaborn-white', 'seaborn-paper']

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel('ABBREV.xlsx')
df = df.sort_values(by=['Iron_(mg)'], ascending=True)
df = df[(df.Shrt_Desc.str.contains('MEAT'))] #
df = df.nlargest(10, 'Iron_(mg)')
df.plot.barh(x='Shrt_Desc', y='Iron_(mg)',color='DarkBlue', legend=False, figsize=(15,10))
plt.gca().invert_yaxis()
plt.style.use('seaborn-pastel')
plt.xlabel(xlabel='Milligrams of Iron', fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
ax1 = plt.axes()
ax1.yaxis.label.set_visible(False)
plt.title('Meats With The Most Iron - USDA (2015)', fontsize=18)
plt.savefig('Meats with The Most Iron - USDA 2015.png', bbox_inches='tight')
# Out:
# /home/erick/Desktop/Projects/Sandbox/lib/python3.5/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_excel('ABBREV.xlsx')
df = df.sort_values(by=['Iron_(mg)'], ascending=True)
df = df[(df.Shrt_Desc.str.contains('FRUITS')) | (df.Shrt_Desc.str.contains('VEGETABLES'))] 
print(df.index.size)
#df = df.nlargest(25, 'Iron_(mg)')
df.plot.barh(x='Shrt_Desc', y='Iron_(mg)',color='DarkBlue', legend=False, figsize=(15,10))
plt.gca().invert_yaxis()
plt.style.use('seaborn-pastel')
plt.xlabel(xlabel='Milligrams of Iron')
# # ax1 = plt.axes()
# # ax1.yaxis.label.set_visible(False)
plt.title('Fruits and Vegetables With The Most Iron - USDA (2015)', fontsize=14)
# plt.savefig('Fruits and Vegetables With The Most Iron - USDA (2015).png', bbox_inches='tight')
# print(df.index.size)
# Out:
# 7
# Text(0.5, 1.0, 'Fruits and Vegetables With The Most Iron - USDA (2015)')

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel('ABBREV.xlsx')
df = df.sort_values(by=['Iron_(mg)'], ascending=True)
df = df[(df.Shrt_Desc.str.contains('BREAD,')) & (df.Shrt_Desc.str.contains('WHEAT') | df.Shrt_Desc.str.contains('WHITE'))] #
df = df.nlargest(12, 'Iron_(mg)')
print(df['Shrt_Desc'])
df.plot.barh(x='Shrt_Desc', y='Iron_(mg)',color='DarkBlue', legend=False)
plt.style.use('seaborn-pastel')
plt.gca().invert_yaxis()
plt.title('Most Iron, Wheat Vs. White Bread - USDA', fontsize=14)
plt.savefig('Most Iron, Wheat Vs. White Bread - USDA.png', bbox_inches='tight')
print(df.head)
# Out:
# 6015                                    BREAD,WHITE WHEAT
# 6545                            WHEAT FLR,WHITE,BREAD,ENR
# 5611                                   BREAD, WHEAT, TSTD
# 5866                             BREAD,WHEAT GERM,TOASTED
# 5613     BREAD,WHITE,COMMLY PREP (INCL SOFT BREAD CRUMBS)
# 5610                                          BREAD,WHEAT
# 5620              BREAD,WHOLE-WHEAT,PREP FROM RECIPE,TSTD
# 5898           BREAD,WHITE,COMMLY PREP,TSTD,LO NA NO SALT
# 5614                         BREAD,WHITE,COMMLY PREP,TSTD
# 5606                                  BREAD,RED-CAL,WHITE
# 5615    BREAD,WHITE,PREP FROM RECIPE,MADE W/NONFAT DRY...
# 5619                   BREAD,WHOLE-WHEAT,PREP FROM RECIPE
# Name: Shrt_Desc, dtype: object
# <bound method NDFrame.head of       NDB_No                                          Shrt_Desc  Water_(g)  \
# 6015   18967                                  BREAD,WHITE WHEAT      39.60
# ...
